# %% [markdown]
# <a href="https://colab.research.google.com/github/RennanRnz/RennanRnz/blob/main/MOD10TAR2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Módulo 10 tarefa 2
#
# Considere a mesma base de dados utilizada na tarefa 1 ```previsao_de_renda.csv```.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %%
df = pd.read_csv('previsao_de_renda.csv')

df = df.drop(['Unnamed: 0', 'mau'], axis=1)

# %% [markdown]
# 1) Com o que você viu em aula, faça uma análise das variáveis qualitativas (posse de imóvel e posse de veículo) para verificar se são boas preditoras de *renda*. Alguma delas parece discriminar *renda* de forma estatisticamente significante?

# %%
sns.lineplot(x='idade', y='renda', hue='posse_de_imovel', data=df, palette=['purple', 'orange'])

plt.title('Preditor de renda por posse de imovel e idade')
plt.xlabel('Idade')
plt.ylabel('Renda')
plt.legend(title='Possuí imóvel?')

plt.show()

# %%
sns.lineplot(x='idade', y='renda', hue='posse_de_veiculo', data=df, palette=['red', 'green'])


plt.title('Preditor de renda por posse de veículo e idade')
plt.xlabel('Idade')
plt.ylabel('Renda')
plt.legend(title='Possuí veículo?')

plt.show()

# %%
colors = ['red', 'green']

perfil_medias_pivot.plot(kind='bar', stacked=True, color=colors)

plt.xlabel('Posse de Imóvel')
plt.ylabel('Renda Média')
plt.title('Gráfico de Médias')
plt.legend(title='Posse de Veículo')
plt.show()

# %% [markdown]
# Se percebe que quanto maior é a renda maiores são os valores True.

# %% [markdown]
# -------------------------------------------------------
