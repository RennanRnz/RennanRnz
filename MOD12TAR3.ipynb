# %% [markdown]
# <a href="https://colab.research.google.com/github/RennanRnz/RennanRnz/blob/main/MOD12TAR3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Regressão 01 - tarefa 03 - transformações em X e Y

# %%
# Importando as bibliotecas necessárias
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from seaborn import load_dataset
import patsy
import statsmodels.api as sm
import statsmodels.formula.api as smf
from scipy import stats

# %matplotlib inline

# %%
# Carregando a base de dados.
tips = load_dataset(name='tips')
tips['tip_pct'] = tips['tip'] / (tips['total_bill'] - tips['tip'])
tips['net_bill'] = tips['total_bill'] - tips['tip']

tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size   tip_pct  net_bill
# 0       16.99  1.01  Female     No  Sun  Dinner     2  0.063204     15.98
# 1       10.34  1.66    Male     No  Sun  Dinner     3  0.191244      8.68
# 2       21.01  3.50    Male     No  Sun  Dinner     3  0.199886     17.51
# 3       23.68  3.31    Male     No  Sun  Dinner     2  0.162494     20.37
# 4       24.59  3.61  Female     No  Sun  Dinner     4  0.172069     20.98

# %% [markdown]
# Carregue os pacotes necessários e a base de gorjetas.
#
# ### I. Modelo no valor da gorjeta

# %% [markdown]
# 1. Crie a matriz de design (e a matriz y) utilizando o Patsy, para um modelo em ```tip```, explicada por ```sex, smoker, diner e net_bill```.

# %%
y, X = patsy.dmatrices(formula_like='tip ~ sex + smoker + time + net_bill', data=tips)

# %%
# Ajustando o modelo
model = sm.OLS(y, X)
results = model.fit()

# %% [markdown]
# 2. Remova as variáveis não significantes.

# %%
# p-valor maior que 0.05 indica que a variável não é significativa.
y, X = patsy.dmatrices(formula_like='tip ~ net_bill', data=tips)
# Ajustando o modelo
modelo_sm1 = sm.OLS(y, X).fit()
print(modelo_sm1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    tip   R-squared:                       0.333
# Model:                            OLS   Adj. R-squared:                  0.330
# Method:                 Least Squares   F-statistic:                     120.6
# Date:                Fri, 08 Nov 2024   Prob (F-statistic):           5.02e-23
# Time:                        16:01:56   Log-Likelihood:                -375.63
# No. Observations:                 244   AIC:                             755.3
# Df Residuals:                     242   BIC:                             762.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.3307      0.168      7.907      0.000       0.999       1.662
# net_bill       0.0993      0.009     10.980      0.000       0.082       0.117
# ==============================================================================
# Omnibus:                       33.873   Durbin-Watson:                   2.123
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               59.942
# Skew:                           0.754   Prob(JB):                     9.63e-14
# Kurtosis:                       4.903   Cond. No.                         43.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# 3. observe o gráfico de resíduos em função de ```net_bill```

# %%
sns.scatterplot(x='net_bill', y=results.resid, data=tips, color = 'darkblue')
plt.axhline(y=0, color='red', linestyle='--')
plt.xlabel('Net Bill')
plt.ylabel('Residuals')
plt.title('Residuals x Net Bill')
plt.show()

# %% [markdown]
# 4. teste transformar ```net_bill``` no log e um polinômio. Escolha o melhor modelo.

# %%
# net_bill para log.
y_log, X_log = patsy.dmatrices('tip ~ np.log(net_bill)', data=tips)
model_log = sm.OLS(y_log, X_log)
results_log = model_log.fit()
print(results_log.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    tip   R-squared:                       0.294
# Model:                            OLS   Adj. R-squared:                  0.292
# Method:                 Least Squares   F-statistic:                     101.0
# Date:                Fri, 08 Nov 2024   Prob (F-statistic):           4.40e-20
# Time:                        16:01:56   Log-Likelihood:                -382.40
# No. Observations:                 244   AIC:                             768.8
# Df Residuals:                     242   BIC:                             775.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept           -1.2575      0.430     -2.924      0.004      -2.104      -0.410
# np.log(net_bill)     1.5695      0.156     10.049      0.000       1.262       1.877
# ==============================================================================
# Omnibus:                       73.945   Durbin-Watson:                   2.045
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              221.148
# Skew:                           1.303   Prob(JB):                     9.51e-49
# Kurtosis:                       6.868   Cond. No.                         17.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# net_bill para polinômio de segundo grau.
y_poly, X_poly = patsy.dmatrices('tip ~ net_bill + np.power(net_bill, 2)', data=tips)
model_poly = sm.OLS(y_poly, X_poly)
results_poly = model_poly.fit()
print(results_poly.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    tip   R-squared:                       0.334
# Model:                            OLS   Adj. R-squared:                  0.329
# Method:                 Least Squares   F-statistic:                     60.55
# Date:                Fri, 08 Nov 2024   Prob (F-statistic):           4.96e-22
# Time:                        16:01:56   Log-Likelihood:                -375.28
# No. Observations:                 244   AIC:                             756.6
# Df Residuals:                     241   BIC:                             767.1
# Df Model:                           2
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 1.0743      0.353      3.039      0.003       0.378       1.770
# net_bill                  0.1288      0.037      3.493      0.001       0.056       0.202
# np.power(net_bill, 2)    -0.0007      0.001     -0.825      0.410      -0.002       0.001
# ==============================================================================
# Omnibus:                       39.745   Durbin-Watson:                   2.097
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               77.849
# Skew:                           0.830   Prob(JB):                     1.25e-17
# Kurtosis:                       5.214   Cond. No.                     2.42e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.42e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Comparação dos modelos com base no R².
print('R² de model_log =', results_log.rsquared)
print('R² de model_poly =', results_poly.rsquared)
# Out:
# R² de model_log = 0.2944412513792952
# R² de model_poly = 0.3344216007656948

# %%
# Escolhendo o melhor modelo com base no maior valor de R²
best_model = 'log' if results_log.rsquared > results_poly.rsquared else 'poly'
print(f'O melhor modelo é com a transformação {best_model} de net_bill.')
# Out:
# O melhor modelo é com a transformação poly de net_bill.

# %% [markdown]
# ### II. Modelo no valor do percentual da gorjeta

# %% [markdown]
# 1. Crie a matriz de design (e a matriz y) utilizando o Patsy, para um modelo no log de ```tip```, explicado por ```sex, smoker, diner e net_bill```.

# %%
tips['log_tip'] = np.log(tips['tip'])
y_log_tip, X_log_tip = patsy.dmatrices(formula_like='np.log(tip) ~ sex + smoker + time + net_bill', data=tips)

#Ajustando o modelo
model_log_tip = sm.OLS(y_log_tip, X_log_tip)
results_log_tip = model_log_tip.fit()

# %% [markdown]
# 2. Remova as variáveis não significantes.

# %%
y, X = patsy.dmatrices(formula_like='np.log(tip) ~ net_bill', data=tips)

#Ajustando o modelo
model_log_tip = sm.OLS(y_log_tip, X_log_tip)
results_log_tip = model_log_tip.fit()

# %% [markdown]
# 3. Observe o gráfico de resíduos em função de ```net_bill```

# %%
sns.scatterplot(x='net_bill', y=results_log_tip.resid, data=tips, color = 'darkblue')
plt.axhline(y=0, color='red', linestyle='--')
plt.xlabel('Net Bill')
plt.ylabel('Residuals')
plt.title('Residuals x Net Bill')
plt.show()

# %% [markdown]
# 4. Teste transformar ```net_bill``` no log e um polinômio. Escolha o melhor modelo.

# %%
y_log_net_bill, X_log_net_bill = patsy.dmatrices('log_tip ~ sex + smoker + time + np.log(net_bill)', data=tips)

#Ajustando o modelo
model_log_net_bill = sm.OLS(y_log_net_bill, X_log_net_bill)
results_log_net_bill = model_log_net_bill.fit()

# %%
y_poly_net_bill, X_poly_net_bill = patsy.dmatrices('log_tip ~ sex + smoker + time + net_bill + np.power(net_bill, 2)', data=tips)

#Ajustando.
model_poly_net_bill = sm.OLS(y_poly_net_bill, X_poly_net_bill)
results_poly_net_bill = model_poly_net_bill.fit()

# %%
print(f' log: {results_log_net_bill.rsquared}')
print(f' poly: {results_poly_net_bill.rsquared}')
# Out:
#  log: 0.3199911749998885
#  poly: 0.3385709725067988

# %%
# best_model.
best_model = 'log' if results_log_net_bill.rsquared > results_poly_net_bill.rsquared else 'poly'
print(f'O melhor modelo é com a transformação {best_model} de net_bill, pois a resultante R² é maior.')
# Out:
# O melhor modelo é com a transformação poly de net_bill, pois a resultante R² é maior.

# %% [markdown]
# 5. Do modelo final deste item, calcule o $R^2$ na escala de ```tip``` (sem o log). Compare com o modelo do item 1. Qual tem melhor coeficiente de determinação?

# %%
tips['pred_tip_log'] = np.exp(results_log_net_bill.fittedvalues)
print('`model_log_net_bill` R²:', tips[['pred_tip_log', 'tip']].corr().iloc[0,1]**2)

tips['pred_tip_pow'] = np.exp(results_poly_net_bill.fittedvalues)
print('`model_poly_net_bill` R²:', tips[['pred_tip_pow', 'tip']].corr().iloc[0,1]**2)
# Out:
# `model_log_net_bill` R²: 0.3308725252412033
# `model_poly_net_bill` R²: 0.3346219964931795

# %% [markdown]
# O modelo ```model_poly_net_bill``` apresenta um melhor coeficiente de determinação.

# %% [markdown]
# ### III. Previsão de renda
#
# Vamos trabalhar a base que você vai usar no projeto do final deste ciclo.
#
# Carregue a base ```previsao_de_renda.csv```.
#
# |variavel|descrição|
# |-|-|
# |data_ref                | Data de referência de coleta das variáveis |
# |index                   | Código de identificação do cliente|
# |sexo                    | Sexo do cliente|
# |posse_de_veiculo        | Indica se o cliente possui veículo|
# |posse_de_imovel         | Indica se o cliente possui imóvel|
# |qtd_filhos              | Quantidade de filhos do cliente|
# |tipo_renda              | Tipo de renda do cliente|
# |educacao                | Grau de instrução do cliente|
# |estado_civil            | Estado civil do cliente|
# |tipo_residencia         | Tipo de residência do cliente (própria, alugada etc)|
# |idade                   | Idade do cliente|
# |tempo_emprego           | Tempo no emprego atual|
# |qt_pessoas_residencia   | Quantidade de pessoas que moram na residência|
# |renda                   | Renda em reais|

# %%
# Carregando a base de dados.
df = pd.read_csv('previsao_de_renda.csv')

# %%
df.info
# Out:
# <bound method DataFrame.info of        Unnamed: 0    data_ref  id_cliente sexo  posse_de_veiculo  \
# 0               0  2015-01-01       15056    F             False
# 1               1  2015-01-01        9968    M              True
# 2               2  2015-01-01        4312    F              True
# 3               3  2015-01-01       10639    F             False
# 4               4  2015-01-01        7064    M              True
# ...           ...         ...         ...  ...               ...
# 14995       14995  2016-03-01       16006    F             False
# 14996       14996  2016-03-01        3722    F             False
# 14997       14997  2016-03-01        6194    F              True
# 14998       14998  2016-03-01        4922    M              True
# 14999       14999  2016-03-01       14651    F             False
#
#        posse_de_imovel  qtd_filhos        tipo_renda           educacao  \
# 0                 True           0        Empresário         Secundário
# 1                 True           0       Assalariado  Superior completo
# 2                 True           0        Empresário  Superior completo
# 3                 True           1  Servidor público  Superior completo
# 4                False           0       Assalariado         Secundário
# ...                ...         ...               ...                ...
# 14995             True           0        Empresário         Secundário
# 14996             True           0       Pensionista  Superior completo
# 14997             True           0       Assalariado  Superior completo
# 14998            False           0        Empresário  Superior completo
# 14999             True           2  Servidor público         Secundário
#
#       estado_civil tipo_residencia  idade  tempo_emprego  \
# 0         Solteiro            Casa     26       6.602740
# 1           Casado            Casa     28       7.183562
# 2           Casado            Casa     35       0.838356
# 3           Casado            Casa     30       4.846575
# 4         Solteiro   Governamental     33       4.293151
# ...            ...             ...    ...            ...
# 14995     Solteiro            Casa     48      13.887671
# 14996     Solteiro            Casa     57            NaN
# 14997       Casado            Casa     45       7.832877
# 14998       Casado            Casa     36       4.298630
# 14999        União            Casa     34       7.219178
#
#        qt_pessoas_residencia     renda
# 0                        1.0   8060.34
# 1                        2.0   1852.15
# 2                        2.0   2253.89
# 3                        3.0   6600.77
# 4                        1.0   6475.97
# ...                      ...       ...
# 14995                    1.0   7990.58
# 14996                    1.0  10093.45
# 14997                    2.0    604.82
# 14998                    2.0   3352.27
# 14999                    4.0   1160.99
#
# [15000 rows x 15 columns]>

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'data_ref', 'id_cliente', 'sexo', 'posse_de_veiculo',
#        'posse_de_imovel', 'qtd_filhos', 'tipo_renda', 'educacao',
#        'estado_civil', 'tipo_residencia', 'idade', 'tempo_emprego',
#        'qt_pessoas_residencia', 'renda'],
#       dtype='object')

# %%
df.shape
# Out:
# (15000, 15)

# %% [markdown]
# 1. Ajuste um modelo de regressão linear simples para explicar ```renda``` como variável resposta, por ```tempo_emprego``` como variável explicativa. Observe que há muitas observações nessa tabela. Utilize os recursos que achar necessário.

# %%
# Removendo valores infinitos e NaNs.
df = df.replace([np.inf, -np.inf], np.nan)
df = df.dropna()

# %%
df.shape
# Out:
# (12427, 15)

# %%
# Ajustando o modelo de regressão linear simples.
reg_renda_simples = smf.ols('renda ~ tempo_emprego', data=df).fit()
df['res_renda_simples'] = reg_renda_simples.resid
print(reg_renda_simples.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  renda   R-squared:                       0.148
# Model:                            OLS   Adj. R-squared:                  0.148
# Method:                 Least Squares   F-statistic:                     2162.
# Date:                Fri, 08 Nov 2024   Prob (F-statistic):               0.00
# Time:                        16:01:57   Log-Likelihood:            -1.2963e+05
# No. Observations:               12427   AIC:                         2.593e+05
# Df Residuals:                   12425   BIC:                         2.593e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept      2177.9041    112.212     19.409      0.000    1957.951    2397.857
# tempo_emprego   510.0119     10.968     46.501      0.000     488.513     531.510
# ==============================================================================
# Omnibus:                    17028.827   Durbin-Watson:                   2.031
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          7679294.474
# Skew:                           7.717   Prob(JB):                         0.00
# Kurtosis:                     123.800   Cond. No.                         15.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Selecionando as variáveis de interesse.
X = df['tempo_emprego']
y = df['renda']

# Adicionando uma coluna de 1s para o intercepto.
X = sm.add_constant(X)

# %%
# Ajustando o modelo de regressão linear.
model = sm.OLS(y, X).fit()

# Imprimindo o sumário do modelo.
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  renda   R-squared:                       0.148
# Model:                            OLS   Adj. R-squared:                  0.148
# Method:                 Least Squares   F-statistic:                     2162.
# Date:                Fri, 08 Nov 2024   Prob (F-statistic):               0.00
# Time:                        16:01:57   Log-Likelihood:            -1.2963e+05
# No. Observations:               12427   AIC:                         2.593e+05
# Df Residuals:                   12425   BIC:                         2.593e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const          2177.9041    112.212     19.409      0.000    1957.951    2397.857
# tempo_emprego   510.0119     10.968     46.501      0.000     488.513     531.510
# ==============================================================================
# Omnibus:                    17028.827   Durbin-Watson:                   2.031
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          7679294.474
# Skew:                           7.717   Prob(JB):                         0.00
# Kurtosis:                     123.800   Cond. No.                         15.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Plotando os dados e a linha de regressão.
plt.scatter(X['tempo_emprego'], y, color = 'darkblue')
plt.plot(X['tempo_emprego'], model.fittedvalues, color='red', linestyle='--')
plt.xlabel('Tempo de Emprego')
plt.ylabel('Renda')
plt.title('Relação entre Tempo de Emprego e Renda')
plt.show()

# %% [markdown]
# 2. Faça uma análise de resíduos. Com os recursos vistos neste módulo, como você melhoraria esta regressão?

# %%
# Calculando os resíduos.
residuals = results.resid

# %%
sm.graphics.tsa.plot_acf(residuals)
plt.title('Gráfico de Autocorrelação dos Resíduos')
plt.show()

# %%
# Transformando a variável resposta com o logaritmo natural.
df['log_renda'] = np.log(df['renda'])
model_log = smf.ols('log_renda ~ tempo_emprego', data=df).fit()
print(model_log.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              log_renda   R-squared:                       0.171
# Model:                            OLS   Adj. R-squared:                  0.171
# Method:                 Least Squares   F-statistic:                     2564.
# Date:                Fri, 08 Nov 2024   Prob (F-statistic):               0.00
# Time:                        16:01:57   Log-Likelihood:                -15150.
# No. Observations:               12427   AIC:                         3.030e+04
# Df Residuals:                   12425   BIC:                         3.032e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         7.8384      0.011    699.851      0.000       7.816       7.860
# tempo_emprego     0.0554      0.001     50.641      0.000       0.053       0.058
# ==============================================================================
# Omnibus:                       33.539   Durbin-Watson:                   2.030
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               33.792
# Skew:                           0.127   Prob(JB):                     4.59e-08
# Kurtosis:                       2.969   Cond. No.                         15.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Adicionando mais variáveis ao modelo.
model_multi = smf.ols('log_renda ~ tempo_emprego + idade + qtd_filhos', data=df).fit()
print(model_multi.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              log_renda   R-squared:                       0.173
# Model:                            OLS   Adj. R-squared:                  0.173
# Method:                 Least Squares   F-statistic:                     865.0
# Date:                Fri, 08 Nov 2024   Prob (F-statistic):               0.00
# Time:                        16:01:57   Log-Likelihood:                -15137.
# No. Observations:               12427   AIC:                         3.028e+04
# Df Residuals:                   12423   BIC:                         3.031e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         7.7690      0.036    217.881      0.000       7.699       7.839
# tempo_emprego     0.0553      0.001     47.858      0.000       0.053       0.058
# idade             0.0011      0.001      1.298      0.194      -0.001       0.003
# qtd_filhos        0.0491      0.010      5.063      0.000       0.030       0.068
# ==============================================================================
# Omnibus:                       32.859   Durbin-Watson:                   2.030
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               33.104
# Skew:                           0.126   Prob(JB):                     6.48e-08
# Kurtosis:                       2.972   Cond. No.                         208.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# 3. Ajuste um modelo de regressão linear múltipla para explicar ```renda``` (ou uma transformação de ```renda```) de acordo com as demais variáveis.

# %%
model = smf.ols('renda ~ sexo + posse_de_veiculo + posse_de_imovel + qtd_filhos + tipo_renda + educacao + estado_civil + tipo_residencia + idade + tempo_emprego + qt_pessoas_residencia', data=df).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  renda   R-squared:                       0.256
# Model:                            OLS   Adj. R-squared:                  0.255
# Method:                 Least Squares   F-statistic:                     178.0
# Date:                Fri, 08 Nov 2024   Prob (F-statistic):               0.00
# Time:                        16:01:57   Log-Likelihood:            -1.2879e+05
# No. Observations:               12427   AIC:                         2.576e+05
# Df Residuals:                   12402   BIC:                         2.578e+05
# Df Model:                          24
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Intercept                        -5626.6247   2500.235     -2.250      0.024   -1.05e+04    -725.776
# sexo[T.M]                         6052.8592    155.859     38.836      0.000    5747.352    6358.367
# posse_de_veiculo[T.True]            48.9098    150.374      0.325      0.745    -245.846     343.666
# posse_de_imovel[T.True]            366.5747    148.723      2.465      0.014      75.054     658.095
# tipo_renda[T.Bolsista]           -1357.7175   2564.833     -0.529      0.597   -6385.188    3669.753
# tipo_renda[T.Empresário]           823.1460    158.826      5.183      0.000     511.822    1134.470
# tipo_renda[T.Pensionista]        -2682.6331   2565.489     -1.046      0.296   -7711.391    2346.125
# tipo_renda[T.Servidor público]     137.0942    236.327      0.580      0.562    -326.143     600.332
# educacao[T.Pós graduação]         1090.5064   1690.396      0.645      0.519   -2222.932    4403.945
# educacao[T.Secundário]             607.3280    765.686      0.793      0.428    -893.536    2108.192
# educacao[T.Superior completo]     1225.5587    768.564      1.595      0.111    -280.947    2732.064
# educacao[T.Superior incompleto]    220.4722    827.097      0.267      0.790   -1400.767    1841.712
# estado_civil[T.Separado]          1161.1096   1182.969      0.982      0.326   -1157.693    3479.912
# estado_civil[T.Solteiro]           819.9016   1158.206      0.708      0.479   -1450.362    3090.165
# estado_civil[T.União]             -475.3334    267.717     -1.776      0.076   -1000.101      49.434
# estado_civil[T.Viúvo]             1053.5626   1229.396      0.857      0.391   -1356.245    3463.370
# tipo_residencia[T.Casa]           -298.3088    575.821     -0.518      0.604   -1427.008     830.390
# tipo_residencia[T.Com os pais]    -388.7990    641.844     -0.606      0.545   -1646.914     869.316
# tipo_residencia[T.Comunitário]    -459.8284   1120.521     -0.410      0.682   -2656.224    1736.567
# tipo_residencia[T.Estúdio]          77.2381   1056.186      0.073      0.942   -1993.051    2147.527
# tipo_residencia[T.Governamental]    73.8042    701.702      0.105      0.916   -1301.641    1449.249
# qtd_filhos                       -1126.6107   1147.916     -0.981      0.326   -3376.703    1123.482
# idade                               42.0025      8.517      4.931      0.000      25.307      58.698
# tempo_emprego                      554.7551     11.044     50.230      0.000     533.107     576.404
# qt_pessoas_residencia             1269.8493   1145.868      1.108      0.268    -976.229    3515.928
# ==============================================================================
# Omnibus:                    17568.773   Durbin-Watson:                   2.034
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          9884998.164
# Skew:                           8.125   Prob(JB):                         0.00
# Kurtosis:                     140.210   Cond. No.                     2.18e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.18e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# 4. Remova as variáveis não significantes e ajuste novamente o modelo. Interprete os parâmetros

# %%
# Removendo as variáveis não significativas.
insignificant_vars = model.pvalues[model.pvalues > 0.05].index.tolist()
significant_vars = [var for var in df.columns if var not in insignificant_vars]

# Ajustando novamente o modelo com as variáveis significativas.
model_sig = smf.ols(f'renda ~ {" + ".join(significant_vars)}', data=df).fit()
print(model_sig.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  renda   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 4.041e+30
# Date:                Fri, 08 Nov 2024   Prob (F-statistic):               0.00
# Time:                        16:01:58   Log-Likelihood:             2.7147e+05
# No. Observations:               12427   AIC:                        -5.429e+05
# Df Residuals:                   12387   BIC:                        -5.426e+05
# Df Model:                          39
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Intercept                            0.0004   7.35e-13   5.92e+08      0.000       0.000       0.000
# data_ref[T.2015-02-01]            2.059e-10   3.88e-12     53.079      0.000    1.98e-10    2.13e-10
# data_ref[T.2015-03-01]            2.024e-10   3.89e-12     52.038      0.000    1.95e-10     2.1e-10
# data_ref[T.2015-04-01]           -3.169e-11   3.88e-12     -8.174      0.000   -3.93e-11   -2.41e-11
# data_ref[T.2015-05-01]            1.039e-11   3.87e-12      2.687      0.007    2.81e-12     1.8e-11
# data_ref[T.2015-06-01]           -3.728e-11   3.88e-12     -9.603      0.000   -4.49e-11   -2.97e-11
# data_ref[T.2015-07-01]            1.503e-10   3.87e-12     38.848      0.000    1.43e-10    1.58e-10
# data_ref[T.2015-08-01]            8.387e-11   3.88e-12     21.604      0.000    7.63e-11    9.15e-11
# data_ref[T.2015-09-01]            8.788e-11   3.86e-12     22.789      0.000    8.03e-11    9.54e-11
# data_ref[T.2015-10-01]            4.419e-11   3.88e-12     11.381      0.000    3.66e-11    5.18e-11
# data_ref[T.2015-11-01]            7.598e-11   3.88e-12     19.559      0.000    6.84e-11    8.36e-11
# data_ref[T.2015-12-01]            -1.13e-12    3.9e-12     -0.290      0.772   -8.77e-12    6.51e-12
# data_ref[T.2016-01-01]            5.492e-12   3.88e-12      1.415      0.157   -2.12e-12    1.31e-11
# data_ref[T.2016-02-01]           -2.046e-11   3.88e-12     -5.273      0.000   -2.81e-11   -1.29e-11
# data_ref[T.2016-03-01]            9.095e-11   3.92e-12     23.225      0.000    8.33e-11    9.86e-11
# sexo[T.M]                          1.68e-12   1.78e-12      0.942      0.346   -1.82e-12    5.18e-12
# posse_de_veiculo[T.True]          9.521e-13   1.55e-12      0.615      0.539   -2.08e-12    3.99e-12
# posse_de_imovel[T.True]          -5.702e-13   1.54e-12     -0.371      0.711   -3.59e-12    2.45e-12
# tipo_renda[T.Bolsista]            5.286e-12   2.64e-11      0.200      0.841   -4.65e-11    5.71e-11
# tipo_renda[T.Empresário]         -4.315e-12   1.64e-12     -2.632      0.009   -7.53e-12    -1.1e-12
# tipo_renda[T.Pensionista]        -1.239e-11   2.64e-11     -0.469      0.639   -6.42e-11    3.94e-11
# tipo_renda[T.Servidor público]    2.075e-12   2.43e-12      0.853      0.394   -2.69e-12    6.84e-12
# educacao[T.Pós graduação]         2.501e-12   1.74e-11      0.144      0.886   -3.16e-11    3.66e-11
# educacao[T.Secundário]            1.876e-12   7.88e-12      0.238      0.812   -1.36e-11    1.73e-11
# educacao[T.Superior completo]     3.411e-13   7.91e-12      0.043      0.966   -1.52e-11    1.58e-11
# educacao[T.Superior incompleto]  -3.979e-13   8.52e-12     -0.047      0.963   -1.71e-11    1.63e-11
# estado_civil[T.Separado]          1.293e-12   3.06e-12      0.422      0.673   -4.71e-12     7.3e-12
# estado_civil[T.Solteiro]          2.785e-12   2.21e-12      1.259      0.208   -1.55e-12    7.12e-12
# estado_civil[T.União]            -7.105e-13   2.75e-12     -0.258      0.796   -6.11e-12    4.69e-12
# estado_civil[T.Viúvo]            -8.789e-12   4.56e-12     -1.926      0.054   -1.77e-11    1.55e-13
# tipo_residencia[T.Casa]           2.842e-13   5.93e-12      0.048      0.962   -1.13e-11    1.19e-11
# tipo_residencia[T.Com os pais]    3.695e-13   6.61e-12      0.056      0.955   -1.26e-11    1.33e-11
# tipo_residencia[T.Comunitário]    1.137e-12   1.15e-11      0.099      0.922   -2.15e-11    2.38e-11
# tipo_residencia[T.Estúdio]        4.547e-13   1.09e-11      0.042      0.967   -2.08e-11    2.18e-11
# tipo_residencia[T.Governamental]  3.922e-12   7.22e-12      0.543      0.587   -1.02e-11    1.81e-11
# id_cliente                        1.116e-15   1.49e-16      7.476      0.000    8.24e-16    1.41e-15
# idade                             3.109e-14   8.43e-14      0.369      0.712   -1.34e-13    1.96e-13
# tempo_emprego                        0.0001   3.14e-12   3.25e+07      0.000       0.000       0.000
# renda                                1.0000   6.25e-15    1.6e+14      0.000       1.000       1.000
# res_renda_simples                 1.999e-07    6.2e-15   3.23e+07      0.000       2e-07       2e-07
# log_renda                         5.116e-13   1.27e-12      0.404      0.686   -1.97e-12    2.99e-12
# ==============================================================================
# Omnibus:                     1236.738   Durbin-Watson:                   0.043
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1021.207
# Skew:                          -0.618   Prob(JB):                    1.77e-222
# Kurtosis:                       2.332   Cond. No.                     3.75e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.62e-23. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# 5. Faça uma análise de resíduos. Avalie a qualidade do ajuste.

# %%
# Calculando os resíduos do modelo múltiplo.
residuals_multi = model_sig.resid

# Criando o gráfico de resíduos do modelo múltiplo.
sns.scatterplot(x=df['tempo_emprego'], y=residuals_multi, color='darkblue')
plt.axhline(y=0, color='red', linestyle='--')
plt.xlabel('Tempo_Emprego', color='red')
plt.ylabel('Resíduos', color='red')
plt.show()

# %% [markdown]
# ------------------------------
